# %% [markdown]
# # Install OpenCV & Other Library

# %%
# !pip install opencv-python opencv-python-headless numpy matplotlib

# %% [markdown]
# # Read And Show Image

# %%
import cv2
import matplotlib.pyplot as plt
# read image
my_img = cv2.imread("/content/image.jpg")
# print(my_img)
# show image
my_img_RGB = cv2.cvtColor(my_img, cv2.COLOR_BGR2RGB)
plt.imshow(my_img_RGB)
plt.title("Original Image")
plt.axis("off")
plt.show()

# %% [markdown]
# # Image color space transformation and storage

# %%
gray = cv2.cvtColor(my_img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap="gray")
plt.title("Gray Image")
plt.axis("off")
plt.show()

# %%
img_HSV = cv2.cvtColor(my_img, cv2.COLOR_BGR2HSV)
plt.imshow(img_HSV)
plt.title("HSV Image")
plt.axis("off")
plt.show()

# %% [markdown]
# # Saving images in different formats

# %%
cv2.imwrite("/content/gray_image.jpg", gray)
cv2.imwrite("/content/hsv_image.jpg", img_HSV)
# Out:
# True
